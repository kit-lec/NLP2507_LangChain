# %% [markdown]
# # 주석 (Comment)

# %%
# 주석 (Comment)
#  프로그램의 실행과는 관계없이
#  코드에 메모등을 남길때 사용

# 1. 한줄 주석:  line comment)
#    '#' 으로 시작
#    '#' 우측부터의 한 줄은 '주석'으로 처리

# 2. 블럭 주석
"""
   이 안의 내용은
   주석으로 처리 됩니다.

"""
None

# %% [markdown]
# # 숫자 (정수, 실수) 데이터

# %%
# 숫자 (정수, 실수) 데이터
# 소숫점이 없으면 '정수' (int : integer)
# 소숫점이 있으면 '실수' (float)
# 컴퓨터 프로그래밍에서는 실수를 floating point number 라 함

# %%
print(10)   # 정수 int
print(10.0) # 실수 float
print(10.)
print(.1)   # 0.1
# Out:
# 10
# 10.0
# 10.0
# 0.1

# %%
10 - 2 * 4
# Out:
# 2

# %%
(10 - 2) * 4
# Out:
# 32

# %%
# 정수와 정수끼리의 연산결과는 정수(int)
# 실수와의 연산결과는 실수(float)
print(4 * 5)
print(4 * 5.0)
# Out:
# 20
# 20.0

# %%
print(4 / 2) # ★ 나눗셈 연산(\) 결과는 언제나 실수 !
# Out:
# 2.0

# %%
# 나눗셈 후 소수점 이하를 버리는 연산자 :  //
# 정수 끼리 딱 떨어지는 결과에 대해서는 정수로 결과가 나옴

print(4 // 2)
print(4 // 1.3)
print(4 / 1.3)
# Out:
# 2
# 3.0
# 3.0769230769230766

# %%
# 5 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-13-2219314525.py in <cell line: 0>()
# ----> 1 5 / 0
#
# ZeroDivisionError: division by zero

# %%
# 나머지 연산자 %
13 % 3
# Out:
# 1

# %%
12.5 % 4.1  # ??  12.5 = 4.1 * 3 + 0.2

# ★★컴퓨터의 실수 계산결과는 오차가 존재할수 있다!
# Out:
# 0.20000000000000107

# %%
# 제곱연산자 **

2 ** 4
# Out:
# 16

# %%
-3 ** 3
# Out:
# -27

# %%
2 ** -1
# Out:
# 0.5

# %%
2 ** (1/2)
# Out:
# 1.4142135623730951

# %% [markdown]
# # 문자열 str
# string

# %%
#----------------------------------
# 문자열 타입 : str (string)
# 문자열 리터럴 만드는 방법
# 1. 쌍따옴표 (double quotation)
# 2. 홀따옴표 (single quotation)
# 3. 쌍따옴표3개
# 4. 홀따옴표3개
# 그밖에
#   f-string
#   r-string
#   ..///

# %%
"Python if fun"
# Out:
# 'Python if fun'

# %%
print("Python if fun")
print('Python if fun')
print("""Python if fun""")
print('''Python if fun''')
# Out:
# Python if fun
# Python if fun
# Python if fun
# Python if fun

# %%
# She's gone

# print('She's gone')
print("She's gone")
# Out:
# She's gone

# %%
# He says "It's OK!"
print('''He says "It's OK!"''')
# Out:
# He says "It's OK!"

# %%
# print("Python is
# fun")

print("Python is \
fun")
# Out:
# Python is fun

# %%
# ''' ~ ''', """ ~ """ 는 줄바꿈 인식.
print('''Python
is fun''')
# Out:
# Python
# is fun

# %%
# 문자열 연결 연산 +
"Hello" + "World"
# Out:
# 'HelloWorld'

# %%
'Hello' + ' ' + 'Python'
# Out:
# 'Hello Python'

# %%
# 문자열 반복 연산 *

"🟨" * 20
# Out:
# '🟨🟨🟨🟨🟨🟨🟨🟨🟨🟨🟨🟨🟨🟨🟨🟨🟨🟨🟨🟨'

# %%
"APT" * 4
# Out:
# 'APTAPTAPTAPT'

# %%
# len() : 문자열 안의 문자 개수
len("Python")
# Out:
# 6

# %%
len("안녕하세요 Python")  # 공백도 하나의 문자!
# Out:
# 12

# %% [markdown]
# # bool타입
# boolean, 논리타입

# %%
# True(참) 혹은 False (거짓) 값만 갖는 타입

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
# true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-37-592217714.py in <cell line: 0>()
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
# 비교연산자(들)
print(20 > 10)
print(20 < 10)
print(20 >= 10)
print(20 <= 10)
print(20 == 10)
print(20 != 10)
# Out:
# True
# False
# True
# False
# False
# True

# %%
10 / 2 == 5
# Out:
# True

# %%
2.1 + 0.2 == 2.3  # ★ 실수연산결과는 오차 있을수 있다 절대 == 비교연산 사용하지 마세요.
# Out:
# False

# %%
2.1 + 0.2
# Out:
# 2.3000000000000003

# %% [markdown]
# # None 타입
# 아무 값도 없는 타입

# %%
None

# %%
print(None)
# Out:
# None

# %% [markdown]
# # type() 함수

# %%
# 사용법: type( 타입을 알고자 하는 값/변수/식 )

# %%
type(10)
# Out:
# int

# %%
type(10.0)
# Out:
# float

# %%
type("10.0")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(None)
# Out:
# NoneType

# %%
print(type(10))
# Out:
# <class 'int'>

# %% [markdown]
# # Indentation
# 들여쓰기

# %%
# 파이썬의 들여쓰기 '열' 맞추어야 한다.
"""
print(100)
 print(200)
print(300)
"""
None

# %% [markdown]
# # 변수 (Variable)

# %%
# 변수(variable) 은 데이터를 담아두는 공간
# 이름을 정해서 담아둔다.  이 이름을 변수이름 (variable name) 이라한다
# 변수의 데이터는 언제든지 변경할수 있다. (변할수 있다!)

# 변수 사용법
#  변수명 = 값

# 이와 같이 = 연산자를 사용하여 변수에 값을 저장하는 것을 대입(assign 한다 라고 하며
# = 을 대입연산자 (assignment operator) 라고 한다

# ★★프로그래머는 변수에 어떠한 '타입'의 어떠한 '값'이 담겨 있는지 놓치면 안된다!   타입! 값!

# 변수명은 대소문자 구분한다

# %%
a = 10   # a 라는 변수에 정수 int 값 10을 '대입'

# %%
print(a)  # a 라는 변수의 값을 읽어서 출력
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
b = 5

# %%
print(b)
print(a + b)
# Out:
# 5
# 15

# %%
# print(c)  # 정의되지 않은 변수는 사용 불가! NameError
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-63-2743823995.py in <cell line: 0>()
# ----> 1 print(c)
#
# NameError: name 'c' is not defined

# %%
print(100, 200, 300)
print(a, b, a + b, a - b)
# Out:
# 100 200 300
# 10 5 15 5

# %%
# print(A) # a 와 A 는 다르다!
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-66-212384544.py in <cell line: 0>()
# ----> 1 print(A)
#
# NameError: name 'A' is not defined

# %%
a = 'hello'   # 존재하는 변수에 새로운 값을 대입하여 변경 가능

# %%
print(a, type(a))
# Out:
# hello <class 'str'>

# %% [markdown]
# # type 변환(형변환) 함수

# %%
# int(), float(), str(), bool() ...

# %%
num = 10
print(num, type(num))
# Out:
# 10 <class 'int'>

# %%
float(num)
# Out:
# 10.0

# %%
str(num)
# Out:
# '10'

# %%
age = 10

# %%
# age + "살"  # str 과 숫자간 + 연산 안됨!

# %%
str(age) + "살"
# Out:
# '10살'

# %%
num1 = "100"
num2 = "200"

# %%
num1, num2
# Out:
# ('100', '200')

# %%
num1 + num2 # '100' + '200' -> 문자열 연결
# Out:
# '100200'

# %%
int(num1) + int(num2)
# Out:
# 300

# %%
# int('python')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-81-2846769038.py in <cell line: 0>()
# ----> 1 int('python')
#
# ValueError: invalid literal for int() with base 10: 'python'

# %%
int(3.14)  # 실수 -> 정수 변환.  소숫점 이하 절삭
# Out:
# 3

# %%
bool(0)  # 0 --> False
# Out:
# False

# %%
bool(100)  # 0 이외의 숫자 -> True
# Out:
# True

# %%
bool('python') # len() 이 0보다 큰 문자열 -> True
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
int(False)
# Out:
# 0

# %%
int(True)
# Out:
# 1

# %% [markdown]
# # 변수명 규칙
# 식별자(identifier) 명명규칙

# %%
#변수명규칙
# 알파벳, 숫자, _  등 사용 가능
# 숫자로는 시작할수 없다
# 변수명에 띄어쓰기 불가
# 특수문자 불가
# 파이썬의 예약어(reserved word)는 변수명으로 사용불가
#      and,  as,  assert,  break,  class,  continue,  def,  del,  elif,  else,  except,  is,
#      finally,  for, from,  global,  if,  import,  in,  lambda,  nonlocal,
#      not,  or,  pass,  raise,  return,  try,  while,  with, yield

# %%
#가능한 변수명
lapTime = 10.2
abc2018 = 10
myLittleBoy = "John"   # camel notation
my_little_boy = "John"  # (파이썬) snake notation, underbar notation
_value23 = 3.14

# %%
# 불가능한 변수명
# 55num = 33
# $%@^ = 33
# $abc = 10
# if = 100

# %% [markdown]
# # del()  : 변수 제거

# %%
name = "John"

print(name, type(name))
# Out:
# John <class 'str'>

# %%
del(name)

# %%
# name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-91-3474671970.py in <cell line: 0>()
# ----> 1 name
#
# NameError: name 'name' is not defined

# %% [markdown]
# # 여러변수를 한 줄에 선언하기

# %%
a = 10
b = 20
c = 30
print(a, b, c)
# Out:
# 10 20 30

# %%
a = 10; b = 20; c = 30;
print(a, b, c)
# Out:
# 10 20 30

# %%
#그러나 파이썬에서는 여러 변수를 선언할때 아래와 같은 표현을 더 많이 사용한다
# 파이썬 스러운 (pythonic) 한 방법

a, b, c = 100, 200, 300
print(a, b, c)
# Out:
# 100 200 300

# %% [markdown]
# # 변수의 값 증감

# %%
a = 10
print(a)
a = a + 1
print(a)
a = a * 2
print(a)
# Out:
# 10
# 11
# 22

# %%
# 복합대입연산자
# +=, -=, *=, /= , //=, %= ....

a += 1   # a = a + 1
print(a)

a /= 2
print(a)
# Out:
# 24
# 12.0

# %% [markdown]
# # 변수 값 바꾸기 (swap)

# %%
a = 11
b = 33
print(a, b)
# Out:
# 11 33

# %%
# 전통적인(?) 방법
a, b = 11, 33
temp = a
a = b
b = temp
print(a, b)
# Out:
# 33 11

# %%
# pythonic 한 방법!
a, b = 111, 333
a, b = b, a
print(a, b)
# Out:
# 333 111
